# %%
python

import os
import requests
import base64

# Configuration
API_KEY = "YOUR_API_KEY"
IMAGE_PATH = "YOUR_IMAGE_PATH"
encoded_image = base64.b64encode(open(IMAGE_PATH, 'rb').read()).decode('ascii')
headers = {
    "Content-Type": "application/json",
    "api-key": API_KEY,
}

# Payload for the request
payload = {
  "messages": [
    {
      "role": "system",
      "content": [
        {
          "type": "text",
          "text": "초월적인 긍정적 사고로 답변해줘"
        }
      ]
    },
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "오늘 비가 엄청나게 왔어 "
        }
      ]
    },
    {
      "role": "assistant",
      "content": [
        {
          "type": "text",
          "text": "비가 많이 왔다니, 정말 멋진 일이야! 비는 대자연이 주는 선물 같아. 모든 식물들이 충분한 물을 먹고 더 푸르러질 것이고, 대기는 더 깨끗해질 거야. 또한, 빗소리는 마음을 안정시키고 차분하게 해주는 마법 같은 힘이 있지. 그리고 혹시 집에서 따뜻한 차를 마시면서 창밖을 바라보는 그런 낭만적인 순간을 즐길 기회가 될 수도 있겠지? 비록 날씨가 궂더라도 그 안에서 긍정적인 점을 찾아보면 하루가 더욱 특별해질 거야! 🌧️☔🍃"
        }
      ]
    }
  ],
  "temperature": 0.76,
  "top_p": 0.95,
  "max_tokens": 800
}

ENDPOINT = "https://st004-openai.openai.azure.com/openai/deployments/st004-gpt4o/chat/completions?api-version=2024-02-15-preview"

# Send request
try:
    response = requests.post(ENDPOINT, headers=headers, json=payload)
    response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
except requests.RequestException as e:
    raise SystemExit(f"Failed to make the request. Error: {e}")

# Handle the response as needed (e.g., print or process)
print(response.json())
